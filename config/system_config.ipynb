# %%
{
  "GeneralConfig": {
    "app_name": "救护车车辆监控系统",
    "version": "1.0.0",
    "auto_connect": true,
    "log_level": "INFO",
    "data_refresh_interval": 1000,
    "backup_interval": 24,
    "max_backup_count": 30
  },
  "MySQLConfig": {
    "host": "localhost",
    "port": 3306,
    "username": "root",
    "password": "gAAAAABoicTuhyFRIjc-j8ndWoFRjZX7riVaIo_KRgXVTbu032NkA8uJY1xfHFqUvZhZ-I69aDh7y9hc8ZTXATGjJmLbCEppF_Qsr8goBIKCxCz8y1t0sjXCJUMB7ZYOB3Yh6vkS7TiRPxEmIzXfcZjFuM6QNnEdISAd316i2K02ON6nBY1mmQx5durUrJNd1SJDcHzA1_0HwYBC7Py5Q_QBuVCqT5ctN1BYhmUJwlcmkJ7kCnIoV5Cl-cjaRkb_4s6SmPZK3ixnqOiu3R8Rmp7QDn2clhhRxiUhWsPzkCns2H7eAHt5gkCNWcdtN8h6sBGAs7OpvxwtMcUTN94RoD1Nx6oocqI_3MnjfRYcss2ZZEFmMCgn51WZvT0CXbfDsHXJptEB3QTB",
    "database": "driving_data",
    "connect_timeout": 5,
    "pool_size": 5,
    "charset": "utf8mb4"
  },
  "RedisConfig": {
    "host": "127.0.0.1",
    "port": 6379,
    "password": "",
    "db": 0,
    "timeout": 10,
    "max_connections": 10
  },
  "InfluxDBConfig": {
    "url": "http://localhost:8086",
    "token": "gAAAAABoicTu3IDiTX9QFEEDqYmbbftYwMEC1Sm-vaoKEj1EDgvBvJ6xUDn8YhStYfYOjYSv6dWZv_OSKl5hymwa9V6D_4Yg-qoFwre3pf7cgzKHRFzsDjbpqC7j2Y5bp_6ejsherbwISg_IUV8-E6YBpKX0NPRfWUCBnmThb4jumhk-h-SR3klTfzhnnGTILVSmUiEeYcLfnV6J_rnzEoO3uMHUQ0RxmasuDItCaFx2aWkXZ2ETNqqWEuS20gSdvuzXmGcgTY0DUwCvqa9z_3-qYIQ8d7AIv4Br6OvqzydPkaEVBdmsSM2YzBLE-tNaCIufHp2-68gxN2iky7pFHRvQeWJzlPh_omEAJWDOMRpboKPR9BzL9TAEKGAZY9xqY6jE0gB5H1SBWjlkSKMAcwtqqatPGOX7gjQHTbYTLePQ-PHlRHGSXqlzOpTUXRQCwftz8AEoh9xsDKyqg3oqqxtbJG1SjcTitnfYgeSOs0DrSHLpLSW0bZOdVlgG-vI0wts6EtAgs-xhcrF-fczaMWj8CTGQOq5hFYVmCBBuzo5kuiJOXRsfRjA=",
    "org": "my-org",
    "bucket": "imu-data"
  },
  "SerialConfig": {
    "port": "",
    "baudrate": 921600,
    "parity": "N",
    "stopbits": 1,
    "bytesize": 8,
    "timeout": 1,
    "reconnect_interval": 5000
  },
  "MQTTConfig": {
    "host": "localhost",
    "port": 1883,
    "username": "gAAAAABoicTu7Qsj0UK-PlCwktqEX6maGVvBHvgNV_LgmQM_8S7I9eNI7zXb3Fa5B5_Mu9Bfq6XZtfbtjKZzDupETu7ZSpcc9J7LDzu00OM-DCA8KWNQk4hPPDhdqfz-racMQcO_UeW4VUxcxQl5vJHDsyvEISRDb2lXO9rDnzlef86XUtK4xPRPZtOoDYOqBh0GbhflBB9xNk1XyC17uq1lcT3ytW6E1zKzjgKAvJ5akEni0qJ-Ck36F5ADmYTQSsq-oBnXlFxfLtY81RjbKuBPbt_0qxahXnfSNMeY4-paPgDEyTDCwNMWhRMsk-izI392OCLZDuS7tBveopvWXKXRaD0pASkyD4csxrnSizeQbGP3PuchUaZZ-j9w8anURNcizM0CV_LL",
    "password": "gAAAAABoicTu_-D-NHYf2gsPZwFoYcLoTKdP90w1oXiAqK1Sf_U58HoICdWODxAvOD_06mZla8F6dobiqjCQsrNeokm4kSHZezYh9t7ebsGXI9uVmUX8ICs9oNu0A-M0SfNILM0st7O03kypVs4TVKjUvPkgc5yWhDLlO8ZMg-b_1bcRI0ilocq72AeDDIw_TZtJJ3mHV1uO9vkxLmIor-Fav76GwMOEFsmKl-gtNVr6SeowTbgtB5pHg-bW3bCNuWLMLHQE1c0lJSLS1flmKnzvpz6Djteb_dXoh-y10pG6jrautC8hNKf8A8ZGJg7db5lVnQa4WrA9scWg61jMQwfknzH25RibUDr3hbnba6jknmVl61BXWrFZW0cHxTA5yO6fWfCjUqHP",
    "client_id": "driving_analysis_client",
    "keepalive": 60,
    "topic": "driving/data",
    "qos": 1,
    "reconnect_interval": 5000
  },
  "UIConfig": {
    "theme": "light",
    "language": "zh_CN",
    "refresh_interval": 1000,
    "show_toolbar": true
  },
  "AnalysisConfig": {
    "enable_real_time": true,
    "save_raw_data": true,
    "event_thresholds": {},
    "overspeed_threshold": 120.0,
    "hard_brake_threshold": -8.0,
    "hard_acceleration_threshold": 5.0,
    "sharp_turn_threshold": 3.0,
    "idle_timeout": 300,
    "maintenance_reminder_distance": 5000,
    "data_smoothing_window": 5
  },
  "PipelineConfig": {
    "buffer_size": 50000,
    "persist_threshold": 10000,
    "processing_threads": 2,
    "batch_size": 100,
    "enable_real_time_analysis": true,
    "enable_data_caching": true,
    "cache_ttl": 3600
  },
  "gaode": {
    "api_key": "529dd90ab6b2a0c968f9693e4aebfeb5",
    "map_type": "normal"
  }
}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File d:\UI重构\config\system_config.json:5
#       1 {
#       2   "GeneralConfig": {
#       3     "app_name": "救护车车辆监控系统",
#       4     "version": "1.0.0",
# ----> 5     "auto_connect": true,
#       6     "log_level": "INFO",
#       7     "data_refresh_interval": 1000,
#       8     "backup_interval": 24,
#       9     "max_backup_count": 30
#      10   },
#      11   "MySQLConfig": {
#      12     "host": "localhost",
#      13     "port": 3306,
#      14     "username": "root",
# ...
